# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardoabdalla/curso-pythonpanda-extensao/blob/main/Segundo_Exemplo_em_Python_PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Segundo exemplo de manipulação de dados usando Python Pandas**
#
# Inserção de dados, remoção de colunas, merge e gráficos
#
# Autor: Eduardo Bruno Abdalla e galera
#
# Data: 9 e 10 de fevereiro de 2023

# %%
# Importar biblioteca PANDAS

import pandas as pd

# %%
# Adicionar excel dos combustiveis.

combustiveis_df = pd.read_excel("ca202102_20230207120945.xlsx")

display(combustiveis_df.head())
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio               Revenda  \
# 0             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 1             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 2             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 3             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 4             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
#
#        CNPJ da Revenda     Nome da Rua Numero Rua Complemento       Bairro  \
# 0   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 1   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 2   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 3   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 4   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
#
#          Cep             Produto Data da Coleta  Valor de Venda  \
# 0  57302-605            GASOLINA     2021-11-01           6.799
# 1  57302-605              ETANOL     2021-11-01           5.299
# 2  57302-605              DIESEL     2021-11-01           5.549
# 3  57302-605  GASOLINA ADITIVADA     2021-11-01           6.899
# 4  57302-605          DIESEL S10     2021-11-01           5.649
#
#    Valor de Compra Unidade de Medida       Bandeira
# 0              NaN        R$ / litro  VIBRA ENERGIA
# 1              NaN        R$ / litro  VIBRA ENERGIA
# 2              NaN        R$ / litro  VIBRA ENERGIA
# 3              NaN        R$ / litro  VIBRA ENERGIA
# 4              NaN        R$ / litro  VIBRA ENERGIA

# %%
# Inserção simples de dados

combustiveis_df['Ativo'] = True

display(combustiveis_df.head())
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio               Revenda  \
# 0             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 1             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 2             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 3             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 4             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
#
#        CNPJ da Revenda     Nome da Rua Numero Rua Complemento       Bairro  \
# 0   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 1   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 2   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 3   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 4   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
#
#          Cep             Produto Data da Coleta  Valor de Venda  \
# 0  57302-605            GASOLINA     2021-11-01           6.799
# 1  57302-605              ETANOL     2021-11-01           5.299
# 2  57302-605              DIESEL     2021-11-01           5.549
# 3  57302-605  GASOLINA ADITIVADA     2021-11-01           6.899
# 4  57302-605          DIESEL S10     2021-11-01           5.649
#
#    Valor de Compra Unidade de Medida       Bandeira  Ativo
# 0              NaN        R$ / litro  VIBRA ENERGIA   True
# 1              NaN        R$ / litro  VIBRA ENERGIA   True
# 2              NaN        R$ / litro  VIBRA ENERGIA   True
# 3              NaN        R$ / litro  VIBRA ENERGIA   True
# 4              NaN        R$ / litro  VIBRA ENERGIA   True

# %%
# Criar uma coluna "Obs" que tenha "MELHOR CIDADE" quando a coluna for INDAIATUBA

combustiveis_df['Obs'] = ["MELHOR CIDADE" if municipio == 'SAO PAULO' else None for municipio in combustiveis_df['Municipio']]

display(combustiveis_df.loc[combustiveis_df['Municipio'].isin(['SAO PAULO','INDAIATUBA', 'CAMPINAS', 'SALTO']),['Municipio','Obs']])
# Out:
#         Municipio            Obs
# 1601    SAO PAULO  MELHOR CIDADE
# 1602    SAO PAULO  MELHOR CIDADE
# 1603    SAO PAULO  MELHOR CIDADE
# 1604    SAO PAULO  MELHOR CIDADE
# 2607     CAMPINAS           None
# ...           ...            ...
# 165925  SAO PAULO  MELHOR CIDADE
# 165926  SAO PAULO  MELHOR CIDADE
# 166122  SAO PAULO  MELHOR CIDADE
# 166123  SAO PAULO  MELHOR CIDADE
# 166124  SAO PAULO  MELHOR CIDADE
#
# [7742 rows x 2 columns]

# %%
# Feito por LEANDRO RODRIGUES

# Como preencher uma coluna 'Valor de Venda - STATUS' que verifica se o valor
# da venda for maior que 6,5 reais, ele informa que está caro, caso contrario, está barato

import numpy as np

combustiveis_df['Status do Valor de Venda'] = np.where(combustiveis_df['Valor de Venda'] > 6.5,'Caro','Barato')

display(combustiveis_df[['Revenda','Valor de Venda', 'Status do Valor de Venda']])
# Out:
#                                            Revenda  Valor de Venda  \
# 0                             POSTO ARAPIRACA LTDA           6.799
# 1                             POSTO ARAPIRACA LTDA           5.299
# 2                             POSTO ARAPIRACA LTDA           5.549
# 3                             POSTO ARAPIRACA LTDA           6.899
# 4                             POSTO ARAPIRACA LTDA           5.649
# ...                                            ...             ...
# 168404  COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA           5.859
# 168405           ABC DISTRIBUICAO DE PETROLEO LTDA           6.580
# 168406           ABC DISTRIBUICAO DE PETROLEO LTDA           4.740
# 168407           ABC DISTRIBUICAO DE PETROLEO LTDA           5.448
# 168408           ABC DISTRIBUICAO DE PETROLEO LTDA           6.580
#
#        Status do Valor de Venda
# 0                          Caro
# 1                        Barato
# 2                        Barato
# 3                          Caro
# 4                        Barato
# ...                         ...
# 168404                   Barato
# 168405                     Caro
# 168406                   Barato
# 168407                   Barato
# 168408                     Caro
#
# [168409 rows x 3 columns]

# %%
# Calcular Postos de Gasloina por Habitantes que temos na Amostragem de Combustiveis em nov/2021

num_habitantes_df = pd.read_csv("ibge_num_habitantes_estimado.csv", sep=";")

num_habitantes_df.rename(columns={"Estado":"Estado - Sigla"}, inplace=True)

display(num_habitantes_df)
# Out:
#          Municipio Estado - Sigla  NumHabitantes2021
# 0   BELO HORIZONTE             MG            2530701
# 1         CAMPINAS             SP            1223237
# 2     CAMPO GRANDE             MS             916001
# 3         CURITIBA             PR            1963726
# 4          GOIANIA             GO            1555626
# 5       INDAIATUBA             SP             260690
# 6            NATAL             RN             803739
# 7           PALMAS             TO             313349
# 8        PENAPOLIS             SP              64098
# 9     PORTO ALEGRE             RS            1492530
# 10     PORTO VELHO             RO             548952
# 11      RIO BRANCO             AC             419452
# 12  RIO DE JANEIRO             RJ            6775561
# 13    SALTO GRANDE             SP               9396
# 14          SANTOS             SP             433991
# 15       SAO PAULO             SP           12396372
# 16     SAO VICENTE             SP             370839
# 17     SERRA NEGRA             SP              29669

# %%
# Fazer um MERGE dos dois dataframes

colunas = ['Municipio', 'Estado - Sigla']

merge_df = combustiveis_df.merge(num_habitantes_df, how="inner", on = colunas)

display(merge_df)
print(merge_df.info())
# Out:
#       Regiao - Sigla Estado - Sigla   Municipio  \
# 0                 CO             GO     GOIANIA
# 1                 CO             GO     GOIANIA
# 2                 CO             GO     GOIANIA
# 3                 CO             GO     GOIANIA
# 4                 CO             GO     GOIANIA
# ...              ...            ...         ...
# 20629             SE             SP  INDAIATUBA
# 20630             SE             SP  INDAIATUBA
# 20631             SE             SP  INDAIATUBA
# 20632             SE             SP  INDAIATUBA
# 20633             SE             SP  INDAIATUBA
#
#                                          Revenda      CNPJ da Revenda  \
# 0                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 1                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 2                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 3                              POSTO DO BOI LTDA   06.880.293/0001-25
# 4                              POSTO DO BOI LTDA   06.880.293/0001-25
# ...                                          ...                  ...
# 20629                     POSTO DOS ESTEVES LTDA   20.763.169/0001-00
# 20630  ABDELNOR VI COMERCIO DE COMBUSTIVEIS LTDA   30.253.289/0001-11
# 20631  ABDELNOR VI COMERCIO DE COMBUSTIVEIS LTDA   30.253.289/0001-11
# 20632  ABDELNOR VI COMERCIO DE COMBUSTIVEIS LTDA   30.253.289/0001-11
# 20633  ABDELNOR VI COMERCIO DE COMBUSTIVEIS LTDA   30.253.289/0001-11
#
#                           Nome da Rua Numero Rua  \
# 0      AVENIDA VEREADOR JOSE MONTEIRO       1854
# 1      AVENIDA VEREADOR JOSE MONTEIRO       1854
# 2      AVENIDA VEREADOR JOSE MONTEIRO       1854
# 3               AVENIDA INDEPENDENCIA      2.908
# 4               AVENIDA INDEPENDENCIA      2.908
# ...                               ...        ...
# 20629                 AVENIDA ITORORO        160
# 20630      AVENIDA PRESIDENTE KENNEDY        496
# 20631      AVENIDA PRESIDENTE KENNEDY        496
# 20632      AVENIDA PRESIDENTE KENNEDY        496
# 20633      AVENIDA PRESIDENTE KENNEDY        496
#
#                                Complemento                Bairro        Cep  \
# 0      QUADRA08                  LOTE  11E  SETOR NEGRAO DE LIMA  74650-300
# 1      QUADRA08                  LOTE  11E  SETOR NEGRAO DE LIMA  74650-300
# 2      QUADRA08                  LOTE  11E  SETOR NEGRAO DE LIMA  74650-300
# 3                                      NaN             VILA NOVA  74645-010
# 4                                      NaN             VILA NOVA  74645-010
# ...                                    ...                   ...        ...
# 20629                                  NaN                CENTRO  13330-055
# 20630                                  NaN         CIDADE NOVA I  13334-170
# 20631                                  NaN         CIDADE NOVA I  13334-170
# 20632                                  NaN         CIDADE NOVA I  13334-170
# 20633                                  NaN         CIDADE NOVA I  13334-170
#
#                   Produto Data da Coleta  Valor de Venda  Valor de Compra  \
# 0                GASOLINA     2021-11-01           6.999              NaN
# 1                  ETANOL     2021-11-01           4.990              NaN
# 2      GASOLINA ADITIVADA     2021-11-01           7.130              NaN
# 3                GASOLINA     2021-11-01           6.990              NaN
# 4                  ETANOL     2021-11-01           4.990              NaN
# ...                   ...            ...             ...              ...
# 20629            GASOLINA     2021-12-28           6.499              NaN
# 20630          DIESEL S10     2021-12-28           5.499              NaN
# 20631  GASOLINA ADITIVADA     2021-12-28           6.699              NaN
# 20632              ETANOL     2021-12-28           4.899              NaN
# 20633            GASOLINA     2021-12-28           6.299              NaN
#
#       Unidade de Medida  Bandeira  Ativo   Obs Status do Valor de Venda  \
# 0            R$ / litro    RAIZEN   True  None                     Caro
# 1            R$ / litro    RAIZEN   True  None                   Barato
# 2            R$ / litro    RAIZEN   True  None                     Caro
# 3            R$ / litro    BRANCA   True  None                     Caro
# 4            R$ / litro    BRANCA   True  None                   Barato
# ...                 ...       ...    ...   ...                      ...
# 20629        R$ / litro  IPIRANGA   True  None                   Barato
# 20630        R$ / litro    RAIZEN   True  None                   Barato
# 20631        R$ / litro    RAIZEN   True  None                     Caro
# 20632        R$ / litro    RAIZEN   True  None                   Barato
# 20633        R$ / litro    RAIZEN   True  None                   Barato
#
#        NumHabitantes2021
# 0                1555626
# 1                1555626
# 2                1555626
# 3                1555626
# 4                1555626
# ...                  ...
# 20629             260690
# 20630             260690
# 20631             260690
# 20632             260690
# 20633             260690
#
# [20634 rows x 20 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20634 entries, 0 to 20633
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Regiao - Sigla            20634 non-null  object
#  1   Estado - Sigla            20634 non-null  object
#  2   Municipio                 20634 non-null  object
#  3   Revenda                   20634 non-null  object
#  4   CNPJ da Revenda           20634 non-null  object
#  5   Nome da Rua               20634 non-null  object
#  6   Numero Rua                20634 non-null  object
#  7   Complemento               3837 non-null   object
#  8   Bairro                    20634 non-null  object
#  9   Cep                       20634 non-null  object
#  10  Produto                   20634 non-null  object
#  11  Data da Coleta            20634 non-null  datetime64[ns]
#  12  Valor de Venda            20634 non-null  float64
#  13  Valor de Compra           0 non-null      float64
#  14  Unidade de Medida         20634 non-null  object
#  15  Bandeira                  20634 non-null  object
#  16  Ativo                     20634 non-null  bool
#  17  Obs                       5220 non-null   object
#  18  Status do Valor de Venda  20634 non-null  object
#  19  NumHabitantes2021         20634 non-null  int64
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(1), object(15)
# memory usage: 3.2+ MB
# None

# %%
# Destruir colunas completamente vazias

merge_df.dropna(axis='columns', inplace=True)

print(merge_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20634 entries, 0 to 20633
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Regiao - Sigla            20634 non-null  object
#  1   Estado - Sigla            20634 non-null  object
#  2   Municipio                 20634 non-null  object
#  3   Revenda                   20634 non-null  object
#  4   CNPJ da Revenda           20634 non-null  object
#  5   Nome da Rua               20634 non-null  object
#  6   Numero Rua                20634 non-null  object
#  7   Bairro                    20634 non-null  object
#  8   Cep                       20634 non-null  object
#  9   Produto                   20634 non-null  object
#  10  Data da Coleta            20634 non-null  datetime64[ns]
#  11  Valor de Venda            20634 non-null  float64
#  12  Unidade de Medida         20634 non-null  object
#  13  Bandeira                  20634 non-null  object
#  14  Ativo                     20634 non-null  bool
#  15  Status do Valor de Venda  20634 non-null  object
#  16  NumHabitantes2021         20634 non-null  int64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(1), object(13)
# memory usage: 2.7+ MB
# None

# %%
colunas=['Regiao - Sigla', 'Nome da Rua', 'Bairro', 'Cep', 'Produto', 'Data da Coleta', 'Valor de Venda','Unidade de Medida', 'Bandeira', 'Ativo',]

merge_df.drop(labels=colunas, axis=1, inplace=True)

print(merge_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20634 entries, 0 to 20633
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Estado - Sigla            20634 non-null  object
#  1   Municipio                 20634 non-null  object
#  2   Revenda                   20634 non-null  object
#  3   CNPJ da Revenda           20634 non-null  object
#  4   Numero Rua                20634 non-null  object
#  5   Status do Valor de Venda  20634 non-null  object
#  6   NumHabitantes2021         20634 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 1.3+ MB
# None

# %%
display(merge_df.head(100))
# Out:
#    Estado - Sigla Municipio                       Revenda  \
# 0              GO   GOIANIA     AERO SETE AUTO POSTO LTDA
# 1              GO   GOIANIA     AERO SETE AUTO POSTO LTDA
# 2              GO   GOIANIA     AERO SETE AUTO POSTO LTDA
# 3              GO   GOIANIA             POSTO DO BOI LTDA
# 4              GO   GOIANIA             POSTO DO BOI LTDA
# ..            ...       ...                           ...
# 95             GO   GOIANIA   AUTO POSTO DONA SANTA LTDA.
# 96             GO   GOIANIA   AUTO POSTO DONA SANTA LTDA.
# 97             GO   GOIANIA  AUTO POSTO ANTENA 104 EIRELI
# 98             GO   GOIANIA  AUTO POSTO ANTENA 104 EIRELI
# 99             GO   GOIANIA  AUTO POSTO ANTENA 104 EIRELI
#
#         CNPJ da Revenda Numero Rua Status do Valor de Venda  NumHabitantes2021
# 0    37.831.484/0001-20       1854                     Caro            1555626
# 1    37.831.484/0001-20       1854                   Barato            1555626
# 2    37.831.484/0001-20       1854                     Caro            1555626
# 3    06.880.293/0001-25      2.908                     Caro            1555626
# 4    06.880.293/0001-25      2.908                   Barato            1555626
# ..                  ...        ...                      ...                ...
# 95   08.232.672/0001-34       1295                     Caro            1555626
# 96   08.232.672/0001-34       1295                   Barato            1555626
# 97   05.634.368/0001-25        356                   Barato            1555626
# 98   05.634.368/0001-25        356                     Caro            1555626
# 99   05.634.368/0001-25        356                   Barato            1555626
#
# [100 rows x 7 columns]

# %%
# Remover as linhas repetidas

merge_df.drop_duplicates(inplace=True)

display(merge_df.head(100))
# Out:
#     Estado - Sigla Municipio                           Revenda  \
# 0               GO   GOIANIA         AERO SETE AUTO POSTO LTDA
# 1               GO   GOIANIA         AERO SETE AUTO POSTO LTDA
# 3               GO   GOIANIA                 POSTO DO BOI LTDA
# 4               GO   GOIANIA                 POSTO DO BOI LTDA
# 7               GO   GOIANIA                     POSTO DN LTDA
# ..             ...       ...                               ...
# 182             GO   GOIANIA             AUTO POSTO LIDER LTDA
# 185             GO   GOIANIA       ALL ' FORTE AUTO POSTO LTDA
# 186             GO   GOIANIA       ALL ' FORTE AUTO POSTO LTDA
# 188             GO   GOIANIA  MARQUES DE CASTRO & GABRIEL LTDA
# 189             GO   GOIANIA  MARQUES DE CASTRO & GABRIEL LTDA
#
#          CNPJ da Revenda Numero Rua Status do Valor de Venda  \
# 0     37.831.484/0001-20       1854                     Caro
# 1     37.831.484/0001-20       1854                   Barato
# 3     06.880.293/0001-25      2.908                     Caro
# 4     06.880.293/0001-25      2.908                   Barato
# 7     05.413.136/0001-47        822                     Caro
# ..                   ...        ...                      ...
# 182   15.225.748/0001-60         98                     Caro
# 185   20.173.970/0001-04        712                   Barato
# 186   20.173.970/0001-04        712                     Caro
# 188   04.397.008/0002-75       1004                     Caro
# 189   04.397.008/0002-75       1004                   Barato
#
#      NumHabitantes2021
# 0              1555626
# 1              1555626
# 3              1555626
# 4              1555626
# 7              1555626
# ..                 ...
# 182            1555626
# 185            1555626
# 186            1555626
# 188            1555626
# 189            1555626
#
# [100 rows x 7 columns]

# %%
# Agrupar e contar quantos postos tem na cidade

postos_por_municipio_df = merge_df.groupby(by=['Estado - Sigla', 'Municipio']).count()

postos_por_municipio_df.drop('CNPJ da Revenda', axis=1, inplace=True)

postos_por_municipio_df.rename(columns={"Revenda":"Número de Postos"}, inplace=True)

display(postos_por_municipio_df)
# Out:
#                                Número de Postos  Numero Rua  \
# Estado - Sigla Municipio
# AC             RIO BRANCO                    88          88
# GO             GOIANIA                      186         186
# MG             BELO HORIZONTE               108         108
# MS             CAMPO GRANDE                 184         184
# PR             CURITIBA                     146         146
# RJ             RIO DE JANEIRO               752         752
# RN             NATAL                         74          74
# RO             PORTO VELHO                   75          75
# RS             PORTO ALEGRE                 131         131
# SP             CAMPINAS                      74          74
#                INDAIATUBA                    59          59
#                SANTOS                        58          58
#                SAO PAULO                    650         650
#                SAO VICENTE                   30          30
# TO             PALMAS                        50          50
#
#                                Status do Valor de Venda  NumHabitantes2021
# Estado - Sigla Municipio
# AC             RIO BRANCO                            88                 88
# GO             GOIANIA                              186                186
# MG             BELO HORIZONTE                       108                108
# MS             CAMPO GRANDE                         184                184
# PR             CURITIBA                             146                146
# RJ             RIO DE JANEIRO                       752                752
# RN             NATAL                                 74                 74
# RO             PORTO VELHO                           75                 75
# RS             PORTO ALEGRE                         131                131
# SP             CAMPINAS                              74                 74
#                INDAIATUBA                            59                 59
#                SANTOS                                58                 58
#                SAO PAULO                            650                650
#                SAO VICENTE                           30                 30
# TO             PALMAS                                50                 50

# %%
#AQUI O FINAL ESTÁ COM PROBLEMA

#Agrupar e contar quantos postos tem na cidade..
postos_por_municipio_df = merge_df.groupby(by=['Estado - Sigla', 'Municipio', 'NumHabitantes2021']).count()
postos_por_municipio_df.reset_index(inplace=True)
#display(postos_por_municipio_df.info())
postos_por_municipio_df.drop('CNPJ da Revenda', axis=1, inplace=True)
postos_por_municipio_df.rename(columns={"Revenda": "NumPostos"}, inplace=True)

postos_por_municipio_df['NumHabitantesPorPostos'] = postos_por_municipio_df['NumHabitantes2021'] / postos_por_municipio_df['NumPostos']
#display(postos_por_municipio_df.info())
display(postos_por_municipio_df)
# Out:
#    Estado - Sigla       Municipio  NumHabitantes2021  NumPostos  Numero Rua  \
# 0              AC      RIO BRANCO             419452         88          88
# 1              GO         GOIANIA            1555626        186         186
# 2              MG  BELO HORIZONTE            2530701        108         108
# 3              MS    CAMPO GRANDE             916001        184         184
# 4              PR        CURITIBA            1963726        146         146
# 5              RJ  RIO DE JANEIRO            6775561        752         752
# 6              RN           NATAL             803739         74          74
# 7              RO     PORTO VELHO             548952         75          75
# 8              RS    PORTO ALEGRE            1492530        131         131
# 9              SP        CAMPINAS            1223237         74          74
# 10             SP      INDAIATUBA             260690         59          59
# 11             SP          SANTOS             433991         58          58
# 12             SP       SAO PAULO           12396372        650         650
# 13             SP     SAO VICENTE             370839         30          30
# 14             TO          PALMAS             313349         50          50
#
#     Status do Valor de Venda  NumHabitantesPorPostos
# 0                         88             4766.500000
# 1                        186             8363.580645
# 2                        108            23432.416667
# 3                        184             4978.266304
# 4                        146            13450.178082
# 5                        752             9010.054521
# 6                         74            10861.337838
# 7                         75             7319.360000
# 8                        131            11393.358779
# 9                         74            16530.229730
# 10                        59             4418.474576
# 11                        58             7482.603448
# 12                       650            19071.341538
# 13                        30            12361.300000
# 14                        50             6266.980000

# %%
# Vamos brincar de gráficos!!!

import matplotlib.pyplot as plt

plt.hist(combustiveis_df['Valor de Venda'])

# Colocar titulo no grafico

plt.title('Preço dos combustiveis - nov/2021')

# Rotulo horizontal e vertical

plt.xlabel("Preço (em Reais)")
plt.ylabel("Quantidade de Coletas")

# Traça a linha vermelha tracejada com o preço médio

plt.axvline(combustiveis_df['Valor de Venda'].mean(), color ='red', linestyle ='dashed')

# Plota o gráfico

plt.show()

# %%
# Segundo gráfico

c_mean = combustiveis_df['Valor de Venda'].groupby(by=combustiveis_df['Produto']).mean()

display(c_mean)
# Out:
# Produto
# DIESEL                5.375682
# DIESEL S10            5.454901
# ETANOL                5.456115
# GASOLINA              6.708741
# GASOLINA ADITIVADA    6.860422
# GNV                   4.392935
# Name: Valor de Venda, dtype: float64

# %%
import seaborn as sns


# Definir a área do gráfico

plt.figure(figsize=(7,4))

#Plotar o Gráfico
c_mean.plot(kind="barh", title="Média de preços por Combustíveis", xlabel="Tipo de Combustível", ylabel="Preço Reais/Litro", color="red", alpha = 0.3) 

#Grid
plt.grid()

# Remover a linha superior e lateral direita

sns.despine()

#Exibe
plt.show()

# %%
display(c_mean)

excel = "por_litro.xlsx"
c_mean.to_excel(excel, "Sumário")
# Out:
# Produto
# DIESEL                5.375682
# DIESEL S10            5.454901
# ETANOL                5.456115
# GASOLINA              6.708741
# GASOLINA ADITIVADA    6.860422
# GNV                   4.392935
# Name: Valor de Venda, dtype: float64

# %%
#Vamor personalizar a planilha Excel...
from openpyxl import load_workbook
from openpyxl.styles import PatternFill, Font, Color, Alignment

#Vai abrir o Excel no openpyxl
wb = load_workbook(excel) # wb = Workbook

#Pegar a planilha certa... usando o Sheet Name (nome da planilha)
ws = wb['Sumário'] # Work Sheet -> planilha atual, ativa, de trabalho

#Vamos pintar o cabeçalho da tabela de "cinzinha"
cinzinha = PatternFill("solid", fgColor="CCCCCC")
coords = ['A1', 'B1']
for coord in coords:
  ws[coord].fill = cinzinha

#Onde o preço do combustível for maior ou igual a 6,5 reais (6.5) pinta a fonte
#de vermelho e deixa negrito...
MAX_ROW = ws.max_row
num_linha = 2
while (num_linha <= MAX_ROW):
  coord = 'B'+str(num_linha) #coord="B{0}".format(num_linha)
  if ws[coord].value >= 6.5:
    ws[coord].font = Font(bold=True, color="FF0000")
  num_linha = num_linha + 1
#Salvar o Excel
wb.save(excel)
